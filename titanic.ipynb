# %%
import pandas as  pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titan= pd.read_csv(r"C:\Users\Vikas\Desktop\pyhton\eda practice data sets\titanic data sets\test.csv")

# %%
titan.head() # sight of data , how is looking
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
titan.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
train=pd.read_csv(r"C:\Users\Vikas\Desktop\pyhton\eda practice data sets\titanic data sets/train.csv")

# %%
pd.set_option("display.max_columns",None)
train.head(25)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
#
# ...

# %%
train.shape
# Out:
# (891, 12)

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Renouf, Mr. Peter Henry  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# Reading a CSV file with specific columns
# Let’s assume that you don’t want all of the columns in your CSV file. You just want 3 of them and you want to get rid of them at the begining. How to do that? Good news! There is a really easy way to do that. We are going to use usecols argument to specify the column names that we want to work with. Let’s work with just PassengerId, Survived, Pclass columns.
# df = pd.read_csv("train.csv", usecols= ["PassengerId", "Survived", "Pclass"])
# df.head() #and add this to see if our code worked

# %% [markdown]
# We can see that count of Age column is 714, mean is 29.6, standard deviation is 14.52 and so on. Thanks to count, we can understand that there are some missing values in this column. We will deal with them later.

# %%
#info method This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage. (Ref-2)
train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
train.isnull().sum().plot(kind="bar")
plt.xlabel("columns")
plt.ylabel("count of missing value")
plt.legend("")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# more nullvalues in two columns which is above 
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
train.isnull().sum().sort_values(ascending=False)/train.shape[0]*100
# Out:
# Cabin          77.104377
# Age            19.865320
# Embarked        0.224467
# Fare            0.000000
# Ticket          0.000000
# Parch           0.000000
# SibSp           0.000000
# Sex             0.000000
# Name            0.000000
# Pclass          0.000000
# Survived        0.000000
# PassengerId     0.000000
# dtype: float64

# %% [raw]
# approximately 20 percent data is missing in age column and 77 percent is in cabin.
#
# more than 77 perc which is categerical we can drop it, no need to impute cause of dtype is not an integer.

# %%
plt.style.use("fivethirtyeight")
train.Survived.value_counts().plot(kind="bar",color="red")
plt.grid()
plt.xlabel('survived')  ,plt.ylabel("count the no of survival and not survival")
plt.show()

# %%
# extract that more 300 people have survived

# %%
sns.set_style("whitegrid")
train["Sex"].value_counts().plot(kind="bar")

# %%
#missing treatment for data
outliers=[]
for i in train['Age']:
    if i>38:
        outliers.append(i)
out=np.array(outliers)
print(out)
out1=pd.Series(out)
out1.count()/train["Age"].count()*100
# Out:
# [54.  58.  39.  55.  40.  66.  42.  40.  49.  65.  45.  46.  59.  71.
#  47.  70.5 54.  45.  47.  42.  51.  55.5 40.5 51.  44.  40.  45.  61.
#  56.  50.  45.  40.  44.  58.  42.  45.5 40.  42.  51.  59.  44.  44.
#  54.  62.  41.  50.  52.  40.  58.  41.  63.  45.  65.  42.  50.  43.
#  54.  40.  61.  45.5 41.  45.  45.  40.  42.  40.  45.  60.  42.  46.
#  39.  51.  44.  42.  50.  64.  45.  52.  49.  65.  50.  48.  47.  48.
#  56.  50.  63.  58.  55.  71.  54.  54.  47.  44.  40.5 50.  39.  45.
#  50.  64.  62.  48.  39.  40.  62.  53.  39.  39.  54.  47.  60.  52.
#  47.  49.  49.  44.  40.  39.  42.  61.  57.  80.  51.  41.  48.  56.
#  58.  50.  40.  47.  43.  40.  70.  43.  60.  60.  52.  44.  49.  42.
#  39.  45.  42.  48.  52.  50.  48.  70.  48.  41.  51.  48.  57.  54.
#  43.  46.  39.  49.  39.  39.  39.  43.  52.  62.  39.  42.  74.  44.
#  45.  51.  41.  48.  42.  47.  47.  56.  39. ]
# 24.789915966386555

# %%
# we will impute the missing values with some analysis model

# %%
#copy the data
train_new=train.copy()
train_new.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_new["Age"]=train.Age.fillna(train.Age.mean())
train_new["Age"].isnull().sum()
# Out:
# 0

# %%
train_new.Age.mean()
# Out:
# 29.699117647058763

# %%
train_new.drop(columns=['Cabin'],axis=1) # this is way to drop column
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
train_new["Embarked"].fillna(method='ffill')
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
train_new.Embarked.isnull().sum()
# Out:
# 2

# %% [markdown]
# # Data visulization
